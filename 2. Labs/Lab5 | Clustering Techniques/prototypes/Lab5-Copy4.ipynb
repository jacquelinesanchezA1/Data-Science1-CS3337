# %% [markdown]
# ## Lab 5

# %%
import pandas as pd
import numpy as np

# pre-processing data tool
from sklearn.preprocessing import StandardScaler

# metric tools
from sklearn.metrics import silhouette_score

# plotting tools
import matplotlib.pyplot as plt

# models
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.cluster import DBSCAN
from sklearn.model_selection import ParameterGrid

# evaluation tools
from sklearn.metrics import silhouette_score

# %% [markdown]
# In this lab, we will use the red wine quality dataset which is attached with the instructions, you can find the description at https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009/data.

# %% [markdown]
# #### Question 1

# %% [markdown]
# Make a data frame with first 11 columns from the original dataset You will apply the different clusters you learned in class to this dataset. Then,processing the dataset, you may deal with the null value, high related factors. (10)

# %%
# Write your code here
wine_df = pd.read_csv('winequality-red.csv')

print(wine_df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
missing_percentage = wine_df.isnull().sum()
print(missing_percentage)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
#  #### Question 2

# %% [markdown]
# Apply K-Means Cluster to the dataset, Apply K-Means Cluster to the dataset, print the Silhouette score (10).

# %%
# 1. Let's standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(wine_df)

# Determine the optimal number of clusters using the Elbow Method
distortions = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    distortions.append(kmeans.inertia_)

# Plot the elbow
plt.figure(figsize=(8, 6))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# Choose the optimal number of clusters based on the elbow method
optimal_k = 3  # For example, choose k=3

# Apply k-means clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
kmeans.fit(X_scaled)

# calculate and print the silhouette score
silhouette_avg = silhouette_score(X_scaled, kmeans.labels_)
print(f'Silhouette Score for k={optimal_k}: {silhouette_avg:.2f}')
# Out:
# Silhouette Score for k=3: 0.17

# %% [markdown]
# #### Question 3

# %% [markdown]
# Apply Hierarchical to the dataset, Apply K-Means Cluster to the dataset, print the Silhouette score.(10)

# %%
# Write your code here

# plotting the hierarchical clusters
Z = linkage(X_scaled, method = 'ward')

plt.figure(figsize=(10,7))
dendrogram(Z)

plt.title('Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# sillhouette coefficient score

k = 3 # the 'optimum' number of cluster suggested by the k-means model
clusters = fcluster(Z, k, criterion='maxclust')

# names of labels(features)
wine_df['Cluster'] = clusters


silhouette_avg = silhouette_score(X_scaled, clusters)
print(f'Silhouette Score: {silhouette_avg:.2f}')
# Out:
# Silhouette Score: 0.14

# %% [markdown]
# #### Question 4

# %% [markdown]
# Apply DBScan to the dataset, print the Silhouette score and best cluster number.(10)

# %%
# Write your code here
dbscan = DBSCAN(eps = 0.5, min_samples = 2)
clusters = dbscan.fit_predict(X_scaled)

wine_df['Cluster'] = clusters

# sillhouette score
if len(set(clusters))>1: 
    silhouette_avg = silhouette_score(X_scaled, clusters)
    print(f'Silhouette Score: {silhouette_avg:.2f}')
          
else:
    print('Silhouette Score: Not defined for a single cluster')
    
# visualizing the clusters
plt.figure(figsize=(10, 7))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering')
plt.show()
# Out:
# Silhouette Score: -0.09

# %%
# Finding the best 'eps' and 'min_samples'
# Define a range of values for eps and min_samples
param_grid = {
    'eps': [i for i in range(1, 11)], 
    'min_samples': [i for i in range(2, 51)]  
}

# Initialize variables to store best parameters and best silhouette score
best_params = None
best_score = -1

# Iterate over all parameter combinations
for params in ParameterGrid(param_grid):
    # Fit DBSCAN with current parameters
#     db = DBSCAN(**params).fit(wine_df)
    db = DBSCAN(**params).fit(X_scaled)
    
    # Compute silhouette score
    labels = db.labels_
    if len(set(labels)) > 1:  # Silhouette score requires at least 2 clusters
#         score = silhouette_score(wine_df, labels)
        score = silhouette_score(X_scaled, labels)
    else:
        score = -1  # Assign a low score if only one cluster is found
    
    # Update best parameters and best score if current score is better
    if score > best_score:
        best_score = score
        best_params = params

# Print the best parameters and corresponding silhouette score
print("Best parameters:", best_params)
print("Best silhouette score:", best_score)
# Out:
# Best parameters: {'eps': 6, 'min_samples': 2}
# Best silhouette score: 0.6969999380456483

# %%
# Define a range of values for eps and min_samples
param_grid = {
    'eps': [i * 0.1 for i in range(1, 11)],  # Adjust the range as needed
    'min_samples': [i for i in range(2, 11)]  # Adjust the range as needed
}

# Initialize variables to store best parameters and best silhouette score
best_params = None
best_score = -1

# Iterate over all parameter combinations
for params in ParameterGrid(param_grid):
    # Fit DBSCAN with current parameters
    db = DBSCAN(**params).fit(X_scaled)
    
    # Compute silhouette score
    labels = db.labels_
    if len(set(labels)) > 1:  # Silhouette score requires at least 2 clusters
        score = silhouette_score(X_scaled, labels)
    else:
        score = -1  # Assign a low score if only one cluster is found
    
    # Update best parameters and best score if current score is better
    if score > best_score:
        best_score = score
        best_params = params

# Fit DBSCAN with the best parameters
db_best = DBSCAN(**best_params).fit(X_scaled)
best_labels = db_best.labels_

# Visualize the clusters
plt.figure(figsize=(10, 7))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=best_labels, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('DBSCAN Clustering with Best Parameters')
plt.show()

# Print the best parameters and corresponding silhouette score
print("Best parameters:", best_params)
print("Best silhouette score:", best_score)

# %% [markdown]
# #### Question 5

# %% [markdown]
# Now make cluster number = 10, redo the cluste process and print the Silhouette scores. (10)

# %%
# Define a range of values for eps and min_samples
param_grid = {
    'eps': [i * 0.1 for i in range(1, 11)],  # Adjust the range as needed
    'min_samples': [i for i in range(2, 11)]  # Adjust the range as needed
}

# Initialize variables to store best parameters and best silhouette score
best_params = None
best_score = -1
target_clusters = 3  # Desired number of clusters

# Iterate over all parameter combinations
for params in ParameterGrid(param_grid):
    # Fit DBSCAN with current parameters
    db = DBSCAN(**params).fit(X_scaled)
    
    # Compute the number of clusters (excluding noise points labeled as -1)
    labels = db.labels_
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    
    # Compute silhouette score if the number of clusters is close to target
    if n_clusters == target_clusters:
        if n_clusters > 1:  # Silhouette score requires at least 2 clusters
            score = silhouette_score(X_scaled, labels)
            # Update best parameters and best score if current score is better
            if score > best_score:
                best_score = score
                best_params = params

# Fit DBSCAN with the best parameters
if best_params:
    db_best = DBSCAN(**best_params).fit(X_scaled)
    best_labels = db_best.labels_

    # Visualize the clusters
    plt.figure(figsize=(10, 7))
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=best_labels, cmap='viridis')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('DBSCAN Clustering with Best Parameters')
    plt.show()

    # Print the best parameters and corresponding silhouette score
    print("Best parameters:", best_params)
    print("Best silhouette score:", best_score)
else:
    print("Couldn't find parameters to achieve exactly 10 clusters.")
# Out:
# Best parameters: {'eps': 0.7000000000000001, 'min_samples': 7}
# Best silhouette score: -0.235949156209201

# %%
# Define a range of values for eps and min_samples
param_grid = {
    'eps': [i * 0.1 for i in range(1, 11)],  # Adjust the range as needed
    'min_samples': [i for i in range(2, 11)]  # Adjust the range as needed
}

# Initialize variables to store best parameters and best silhouette score
best_params = None
best_score = -1
target_clusters = 10  # Desired number of clusters

# Iterate over all parameter combinations
for params in ParameterGrid(param_grid):
    # Fit DBSCAN with current parameters
    db = DBSCAN(**params).fit(X_scaled)
    
    # Compute the number of clusters (excluding noise points labeled as -1)
    labels = db.labels_
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    
    # Compute silhouette score if the number of clusters is close to target
    if n_clusters == target_clusters:
        if n_clusters > 1:  # Silhouette score requires at least 2 clusters
            score = silhouette_score(X_scaled, labels)
            # Update best parameters and best score if current score is better
            if score > best_score:
                best_score = score
                best_params = params

# Fit DBSCAN with the best parameters
if best_params:
    db_best = DBSCAN(**best_params).fit(X_scaled)
    best_labels = db_best.labels_

    # Visualize the clusters
    plt.figure(figsize=(10, 7))
    plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=best_labels, cmap='viridis')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('DBSCAN Clustering with Best Parameters')
    plt.show()

    # Print the best parameters and corresponding silhouette score
    print("Best parameters:", best_params)
    print("Best silhouette score:", best_score)
else:
    print("Couldn't find parameters to achieve exactly 10 clusters.")
# Out:
# Best parameters: {'eps': 0.4, 'min_samples': 4}
# Best silhouette score: -0.3527326345788327

# %% [markdown]
# #### Question 6

# %% [markdown]
# Match the cluster results with the 12th column, "quality", to add a column named as "prediction". For example, find all the data with quality = 6, and count the number of cluster numbers if in total there are 120 data with quality = 6 and 100 of their cluster numbers are 2, then all the data with cluster number = 2 should be marked as 6 in the "prediction" column. (10)

# %%
# Write your code here

# %% [markdown]
# #### Question 7

# %% [markdown]
# Now get the accracy score with the "Prediction" column and "quality" column.(10)

# %%
# Write your code here

# %% [markdown]
# #### Question 8

# %% [markdown]
# Now seperate the data with 80% training set and 20% testing set and train a ANN model with the training set and print the accuracy score of the testing set.(10)

# %%
# Write your code here

# %% [markdown]
# #### Question 9

# %% [markdown]
# Compare the accuracy scores of the previous four models, which one is the best?(10)

# %% [markdown]
# Write your code here

# %% [markdown]
# #### Question 10

# %% [markdown]
# Do you think we can use the unsupervised cluster models tobe a classifier in this way? Why?(10)

# %% [markdown]
# Write your code here
