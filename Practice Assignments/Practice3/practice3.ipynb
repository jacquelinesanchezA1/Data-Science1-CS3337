# %% [markdown]
# ## Intro to Matplotlib

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is used along with NumPy to provide an environment that is an effective open source alternative to MatLab. Thus, this may feel very familiar to you if you'vre ever used MatLab. Please note that Matplotlib is not the only tool for creating data visualuzation in Python. Other common libraries include [seaborn](https://seaborn.pydata.org/), [plotly](https://plotly.com/), and even [pandas](https://pandas.pydata.org/docs/user_guide/visualization.html) has some built in functions for quick plotting.

# %% [markdown]
# Note: seaborn is built on top of Matplotlib, so it will be easy to pick up after going through this lab (:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The cell below is optional. It just makes our figure size 15x5 and adds a darkgrid background by defautl. Feel free to experiment with these values if you'd like , but you'll have to restart the kernel and run all to see any changes.

# %%
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 5 # dimenstion 15x5 
sns.set_style('darkgrid')

# %% [markdown]
# ## Plotting Numpy Arrays

# %% [markdown]
# Let's begin by creating some numpy arrays and plotting them. We can create a sime x, y graph using **plt.plot(x,y)**. We cna then display this by calling **plt.show()**.

# %%
x = np.linspace(0,20) # this is the start and end index of the x axis
y = np.sin(x) # linear function
plt.plot(x,y) # plotting 
plt.show() # display

# %% [markdown]
# It's would also be nice to add titles and axis labels to our graphs. We can accomplish this using **plt.title()** and **plt.x/ylabel()**.

# %%
plt.plot(x,y)
plt.title('My Graph Title')
plt.xlabel('My x-axis label')
plt.ylabel('My y-axis label')
plt.show()

# %% [markdown]
# **Note to self: you must exclusively invoke every function using the alias you defined at the top of this notebook. 'plt' was defined to envoke matplotlib.plyplot!**

# %%
plotty.plot(x,y)
plotty.title('My Graph Title')
plotty.xlabel('My x-axis label')
plotty.ylabel('My y-axis label')
plotty.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plotty.plot(x,y)
#       2 plotty.title('My Graph Title')
#       3 plotty.xlabel('My x-axis label')
#
# NameError: name 'plotty' is not defined

# %% [markdown]
# **Note: Make sure to add any titles/labels and such before calling plt.calling plt.show(). Otherwise they will not show up.**

# %% [markdown]
# We'll sometimes like tot plot more than one function together, which can be done by calling **plt.plot()** a second time in the same cell. However, make sure to add an additional **label** parameter when doing this to give each plot/function a unique label name. That way we can then call **plt.legend()**, which will automatically add a legend for us and let us know which plot is which.

# %%
plt.plot(x, np.sin(x), label = 'y = sin(x)')
plt.plot(x, np.cos(x), label = 'y = cos(x)')
plt.title('Sine and Cosine Functions ')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Assigns a colot to each plot alonf with it's corresponding label name to display
plt.legend()
plt.show()
